# %% [markdown]
# # Question 1
#
# Write a python function that returns $2\sin(x^2) + \ln(|x|) + 1$ for a given real number $x$.

# %%
import numpy as np
from math import sin,log

def func(x):
    
    result=2*sin(x**2)+log(abs(x))+1
    
    return result

func(30)
# Out:
# 6.396803930506096

# %% [markdown]
# # Question 2
#
# Write a python function that takes
#
# * A function `f(x)`
# * A pair of real numbers `(a,b)`
# * An integer `N`
#
# as input and returns the Riemann sum of `f(x)` on the interval `[a,b]` with `N` equal subdivisions.

# %%
f = lambda x:2*x

def func(f,interval,n):
    a,b=interval
    dx=(abs(b-a)+1)/n
    x=np.linspace(a,b,n)
    
    return np.sum(f(x)*dx)

a=func(f,(1,4),4)
a
# Out:
# 20.0

# %% [markdown]
# # Question 3
#
# * Pull 100 uniformly random numbers from the interval $[0,1]$ as an array `xs`.
# * Add 0 at the beginning of the array, and 1.0 at the end.
# * Sort the array `xs` from smallest to the largest.
# * Calculate its discrete derivative `ys`, i.e. let $y_i = x_{i+1} - x_i$

# %%
import random 
np.random.seed()

xs=np.random.uniform(0,1,size=100)
xs=np.append(xs,[0,1])
xs.sort()

ys=np.diff(xs)
ys
# Out:
# array([0.0020287 , 0.00175636, 0.03354779, 0.0008894 , 0.00332103,
#        0.00393747, 0.01088887, 0.01170763, 0.00253209, 0.00027995,
#        0.01433343, 0.00249452, 0.00358489, 0.01475461, 0.00141683,
#        0.01834945, 0.0057703 , 0.00412356, 0.00278855, 0.00563002,
#        0.00169803, 0.00208186, 0.00596452, 0.00129055, 0.01409369,
#        0.03193654, 0.00988777, 0.002846  , 0.00051517, 0.0166282 ,
#        0.01059745, 0.00010994, 0.0302436 , 0.00464239, 0.02862541,
#        0.00326248, 0.01196217, 0.00294938, 0.00190188, 0.00341245,
#        0.00133   , 0.0118126 , 0.03067973, 0.00050361, 0.00520909,
#        0.01879722, 0.00306963, 0.00106813, 0.00446735, 0.00338745,
#        0.01360614, 0.02014216, 0.01230698, 0.0140173 , 0.01987702,
#        0.02348281, 0.00652   , 0.00419383, 0.03649541, 0.01349675,
#        0.00578308, 0.02092513, 0.0047148 , 0.00949148, 0.0380089 ,
#        0.00922465, 0.01141915, 0.00524575, 0.01565865, 0.02170378,
#        0.00598212, 0.00733323, 0.00186358, 0.00072975, 0.02613312,
#        0.0115314 , 0.00280364, 0.03373586, 0.00458452, 0.00219735,
#        0.00482254, 0.00530335, 0.0048712 , 0.02001687, 0.00216984,
#        0.00074895, 0.02669634, 0.00218557, 0.00403969, 0.00464538,
#        0.00056432, 0.04938904, 0.01440215, 0.00230378, 0.00242803,
#        0.00693354, 0.01532378, 0.00302136, 0.01412472, 0.0009171 ,
#        0.00277438])

# %% [markdown]
# # Question 4
#
# * Pull 100 uniformly random numbers from the interval $[0,1]$ into an array `xs`.
# * Pull 100 random numbers from the Gaussion distribution with $\mu=0$ and $\sigma=1.0$ into an array `ys`.
# * Scatter plot `xs` against `ys` using `matplotlib`

# %%
import matplotlib.pyplot as plt

xs=np.random.uniform(0,1,100)
ys=np.random.normal(loc=0,scale=1,size=100)

plt.scatter(xs,ys)

# %% [markdown]
# # Question 5
#
# Using the `numpy` library
#
#
# * Pull a random $100\times 100$ matrix
# * Calculate its 100-th power
# * Calculate its eigen-values
# * Calculate is [Singular Value Decomposition](https://numpy.org/doc/stable/reference/generated/numpy.linalg.svd.html)

# %%
matrix=np.random.rand(100,100)

matrix=np.linalg.matrix_power(matrix,100)

w,v=np.linalg.eig(matrix)
u,s,singvd=np.linalg.svd(matrix)
singvd
# Out:
# array([[-1.05932048e-01, -1.09953581e-01, -9.69133983e-02, ...,
#         -1.03991168e-01, -1.01741896e-01, -9.17524844e-02],
#        [ 4.48503612e-04,  5.96088824e-03,  8.15460414e-02, ...,
#          9.16360268e-03, -2.50793597e-02,  2.15483449e-02],
#        [-1.08302785e-02,  3.50064668e-01, -7.09144894e-01, ...,
#         -3.06409449e-02, -9.40623284e-03, -8.94100748e-03],
#        ...,
#        [ 0.00000000e+00,  1.61836685e-02,  1.89719681e-02, ...,
#         -3.75327069e-02,  3.52441381e-02, -3.65408250e-02],
#        [ 4.68557219e-01, -1.42544804e-02, -4.25790238e-02, ...,
#          6.87789482e-02, -2.28019010e-02, -1.61001367e-03],
#        [-8.66255608e-01, -7.77939559e-02, -7.93093749e-02, ...,
#          5.38102493e-02,  6.18451885e-03,  1.28103166e-02]])

# %% [markdown]
# # Question 6
#
# * Pull the text of a novel by Dickens from the website of [Gutenberg Project](https://www.gutenberg.org/)
# * Remove all non-alphanumeric characters
# * Split the text into words and convert them into lower case
# * Count the number of distinct words in the  text
# * Count how many times each word occurs within the text

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re
from collections import Counter
from urllib import request
from bs4 import BeautifulSoup
import string 

url="https://www.gutenberg.org/files/564/564-h/564-h.htm"

html = request.urlopen(url).read().decode('utf8')
parsedHTML = BeautifulSoup(html, "html.parser")

readableText = parsedHTML.get_text() 
readable=readableText
words=readable.split()
words=words[0:500]  #how many words do you want to count

counter = dict() 

for i in range(len(words)):
    
    words[i]=words[i].lower()
    words[i] = words[i].translate(words[i].maketrans("", "", string.punctuation)) 
    
for word in words:  
    if word in counter: 
        counter[word] = counter[word] + 1
    else: 
        counter[word] = 1
for key in list(counter.keys()): 
    print(key, ":", counter[key])
# Out:
# the : 42
# mystery : 5
# of : 23
# edwin : 5
# drood : 5
# by : 7
# charles : 3
# dickens : 3
# project : 3
# gutenberg : 3
# ebook : 6
# illustrated : 1
# luke : 1
# fildes : 1
# this : 5
# is : 9
# for : 3
# use : 1
# anyone : 1
# anywhere : 1
# in : 12
# united : 2
# states : 2
# and : 16
# most : 1
# other : 1
# parts : 1
# world : 1
# at : 4
# no : 4
# cost : 1
# with : 3
# almost : 1
# restrictions : 1
# whatsoever : 1
# you : 3
# may : 2
# copy : 1
# it : 12
# give : 1
# away : 1
# or : 3
# reuse : 1
# under : 2
# terms : 1
# license : 1
# included : 1
# online : 1
# wwwgutenbergorg : 1
# if : 1
# are : 4
# not : 2
# located : 2
# youll : 1
# have : 1
# to : 5
# check : 1
# laws : 1
# country : 1
# where : 2
# before : 1
# using : 1
# title : 1
# author : 1
# release : 1
# date : 1
# 28 : 1
# 2020 : 1
# 564 : 1
# file : 1
# was : 1
# first : 2
# posted : 1
# on : 3
# april : 1
# 15 : 1
# 1996 : 1
# language : 1
# english : 3
# character : 1
# set : 3
# encoding : 1
# iso646us : 1
# usascii : 1
# start : 1
# transcribed : 1
# from : 4
# chapman : 1
# hall : 1
# 1914 : 1
# edition : 1
# david : 1
# price : 1
# email : 1
# ccx074pglaforg : 1
# chapter : 1
# i—the : 1
# dawn : 1
# an : 2
# ancient : 2
# cathedral : 4
# tower : 4
# how : 2
# can : 2
# be : 4
# here : 2
# wellknown : 1
# massive : 1
# gray : 1
# square : 1
# its : 2
# old : 2
# that : 4
# there : 1
# spike : 5
# rusty : 2
# iron : 1
# air : 1
# between : 1
# eye : 1
# any : 1
# point : 1
# real : 1
# prospect : 1
# what : 1
# intervenes : 1
# who : 1
# has : 4
# up : 2
# maybe : 1
# sultan’s : 1
# orders : 1
# impaling : 1
# a : 11
# horde : 1
# turkish : 1
# robbers : 1
# one : 2
# so : 2
# cymbals : 1
# clash : 1
# sultan : 1
# goes : 1
# his : 3
# palace : 1
# long : 1
# procession : 1
# ten : 2
# thousand : 2
# scimitars : 1
# flash : 1
# sunlight : 1
# thrice : 1
# dancinggirls : 1
# strew : 1
# flowers : 1
# then : 1
# follow : 1
# white : 1
# elephants : 1
# caparisoned : 1
# countless : 1
# gorgeous : 1
# colours : 1
# infinite : 1
# number : 1
# attendants : 1
# still : 2
# rises : 2
# background : 1
# cannot : 1
# writhing : 1
# figure : 1
# grim : 1
# stay : 1
# low : 1
# thing : 1
# as : 2
# top : 1
# post : 1
# bedstead : 2
# tumbled : 1
# all : 1
# awry : 1
# some : 1
# vague : 1
# period : 1
# drowsy : 1
# laughter : 1
# must : 1
# devoted : 1
# consideration : 1
# possibility : 1
# shaking : 1
# head : 1
# foot : 1
# man : 1
# whose : 1
# scattered : 1
# consciousness : 1
# thus : 1
# fantastically : 1
# pieced : 1
# itself : 1
# together : 1
# length : 1
# supports : 1
# trembling : 1
# frame : 1
# upon : 3
# arms : 1
# looks : 1
# around : 1
# he : 2
# meanest : 1
# closest : 1
# small : 1
# rooms : 1
# through : 1
# ragged : 1
# windowcurtain : 1
# light : 2
# early : 1
# day : 1
# steals : 1
# miserable : 1
# court : 1
# lies : 1
# dressed : 2
# across : 2
# large : 1
# unseemly : 1
# bed : 2
# indeed : 1
# given : 1
# way : 1
# weight : 1
# lying : 1
# also : 2
# longwise : 1
# chinaman : 1
# lascar : 1
# haggard : 1
# woman : 1
# two : 1
# sleep : 1
# stupor : 1
# last : 1
# blowing : 1
# kind : 1
# pipe : 1
# kindle : 1
# she : 1
# blows : 1
# shading : 1
# her : 1
# lean : 1
# hand : 1
# concentrates : 1
# red : 1
# spark : 1
# serves : 1
# dim : 1

# %% [markdown]
# # Question 7
#
# * Write a python function `CountWords` that takes the URL for a text and returns the number of unique words within the text.
# * Write a python function `Top20Words` that takes the URL for a text and returns the most frequently appearing top 20 words within the text.

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re
from collections import Counter
from urllib import request
from bs4 import BeautifulSoup
import string 
from re import sub


def Countwords(url):
    html = request.urlopen(url).read().decode('utf8')
    parsedHTML = BeautifulSoup(html, "html.parser")
    readableText = parsedHTML.get_text() 
    readable=readableText
    words=readable.split()
    numberofunique=set(words)
    return len(numberofunique)

def Top20Words(url):
    html = request.urlopen(url).read().decode('utf8')
    parsedHTML = BeautifulSoup(html, "html.parser")
    readableText = parsedHTML.get_text() 
    readable=readableText
    words=readable.split()
    numbers=Counter(words)
    sort=sorted(numbers,key=numbers.get,reverse=True)
    return sort[0:20]

mostcommon=Top20Words(url)

unique=Countwords(url)

# %%
mostcommon
# Out:
# ['the',
#  'and',
#  'of',
#  'to',
#  'a',
#  'in',
#  'I',
#  'his',
#  'that',
#  'Mr.',
#  'he',
#  'with',
#  'you',
#  'it',
#  'is',
#  'as',
#  'for',
#  'was',
#  'be',
#  'have']

# %%
unique
# Out:
# 17420

# %% [markdown]
# # Question 8
#
# * Pull the [IMKB](https://archive.ics.uci.edu/ml/machine-learning-databases/00247/data_akbilgic.xlsx) data from UCI using pandas.
# * Plot the TL based ISE and USD based ISE columns together in the same graph.
# * Calculate how many times `NIKKEI` was higher than `FTSE`.

# %%
import pandas as pd

df = pd.read_excel ('data_akbilgic.xlsx')

#i couldnt read xlsx file, i sent it with google colab already
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-33-d34c4d32f622> in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_excel ('data_akbilgic.xlsx')
#       4
#       5 #i couldnt read xlsx file
#
# ~\Desktop\sample_project\env\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~\Desktop\sample_project\env\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     822         self._io = stringify_path(io)
#     823
# --> 824         self._reader = self._engines[engine](self._io)
#     825
#     826     def __fspath__(self):
#
# ~\Desktop\sample_project\env\lib\site-packages\pandas\io\excel\_xlrd.py in __init__(self, filepath_or_buffer)
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      20         import_optional_dependency("xlrd", extra=err_msg)
# ---> 21         super().__init__(filepath_or_buffer)
#      22
#      23     @property
#
# ~\Desktop\sample_project\env\lib\site-packages\pandas\io\excel\_base.py in __init__(self, filepath_or_buffer)
#     351             self.book = self.load_workbook(filepath_or_buffer)
#     352         elif isinstance(filepath_or_buffer, str):
# --> 353             self.book = self.load_workbook(filepath_or_buffer)
#     354         elif isinstance(filepath_or_buffer, bytes):
#     355             self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# ~\Desktop\sample_project\env\lib\site-packages\pandas\io\excel\_xlrd.py in load_workbook(self, filepath_or_buffer)
#      34             return open_workbook(file_contents=data)
#      35         else:
# ---> 36             return open_workbook(filepath_or_buffer)
#      37
#      38     @property
#
# ~\Desktop\sample_project\env\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows, ignore_workbook_corruption)
#     168     # files that xlrd can parse don't start with the expected signature.
#     169     if file_format and file_format != 'xls':
# --> 170         raise XLRDError(FILE_FORMAT_DESCRIPTIONS[file_format]+'; not supported')
#     171
#     172     bk = open_workbook_xls(
#
# XLRDError: Excel xlsx file; not supported

# %% [markdown]
# # Question 9
#
# Using the [networkx](https://networkx.org/) library
#
# * Get the [adjacency matrix](https://en.wikipedia.org/wiki/Adjacency_matrix) of the [Peterson graph](https://en.wikipedia.org/wiki/Petersen_graph).
# * Calculate its eigen-values and eigen-vectors using the [numpy](https://numpy.org/) library.
# * Repeat the same for a [random 3-regular graph on 10 vertices](https://networkx.org/documentation/networkx-1.10/reference/generated/networkx.generators.random_graphs.random_regular_graph.html).

# %%
import networkx as nx
import matplotlib.pyplot as plt

Graph = nx.petersen_graph()
nx.draw_shell(Graph, nlist=[range(3, 15), range(10)], font_weight='bold',node_color=range(10),cmap=plt.cm.Blues,font_color='r',style='dotted')
plt.show()

A=np.array(nx.adjacency_matrix(Graph).todense())
v,w=np.linalg.eig(A)

# %%
a=nx.random_regular_graph(3,10)

nx.draw_shell(a, nlist=[range(3, 15), range(10)], font_weight='bold',node_color=range(10),cmap=plt.cm.Blues,font_color='r',style='dotted')
plt.show()

Matrix=np.array(nx.adjacency_matrix(a).todense())
v,w=np.linalg.eig(Matrix)

# %%
a=nx.random_regular_graph(3,10)

nx.draw_shell(a, nlist=[range(3, 15), range(10)], font_weight='bold',node_color=range(10),cmap=plt.cm.Blues,font_color='r',style='dotted')
plt.show()

Matrix=np.array(nx.adjacency_matrix(a).todense())
v,w=np.linalg.eig(Matrix)

# %%
a=nx.random_regular_graph(3,10)

nx.draw_shell(a, nlist=[range(3, 15), range(10)], font_weight='bold',node_color=range(10),cmap=plt.cm.Blues,font_color='r',style='dotted')
plt.show()

Matrix=np.array(nx.adjacency_matrix(a).todense())
v,w=np.linalg.eig(Matrix)
