# %% [markdown]
# # Question 1
#
# Write a python function that returns $2\sin(x^2) + \ln(|x|) + 1$ for a given real number $x$.

# %%
import numpy as np

def calc(x):
    a=2*np.sin(x**2)+np.log(abs(x))+1
    return a

calc(30)
# Out:
# 6.396803930506096

# %% [markdown]
# # Question 2
#
# Write a python function that takes
#
# * A function `f(x)`
# * A pair of real numbers `(a,b)`
# * An integer `N`
#
# as input and returns the Riemann sum of `f(x)` on the interval `[a,b]` with `N` equal subdivisions.

# %%
f = lambda x:2*x

def func(f,a,b,n):
    dx=(b-a+1)/n
    x=np.linspace(a,b,n)
    return np.sum(f(x)*dx)

a=func(f,1,4,4)

a
# Out:
# 20.0

# %% [markdown]
# # Question 3
#
# * Pull 100 uniformly random numbers from the interval $[0,1]$ as an array `xs`.
# * Add 0 at the beginning of the array, and 1.0 at the end.
# * Sort the array `xs` from smallest to the largest.
# * Calculate its discrete derivative `ys`, i.e. let $y_i = x_{i+1} - x_i$

# %%
import random 
np.random.seed()

xs=np.random.random(100)
xs=np.sort(xs)

ys=[]
for i in range(len(xs)):
    if i==len(xs)-1:
        break;
    a=xs[i+1]-xs[i]
    ys.append(a)
ys
# Out:
# [0.007405463009235502,
#  0.0005789964235481948,
#  0.011703986255372278,
#  0.042975843879925146,
#  0.01571482383321643,
#  0.006796753847735704,
#  0.0008271108545411243,
#  0.018499943181637724,
#  0.0067750594874951275,
#  0.006426376856949245,
#  0.011611355124217293,
#  0.02209495046949017,
#  0.0032110917332578426,
#  0.0013798878290545158,
#  0.018538848673492203,
#  0.018284306442728493,
#  0.0009287524006936776,
#  0.011391680269277504,
#  0.004162209532127759,
#  0.002541042122520043,
#  0.0019025771380271062,
#  0.02433256037856235,
#  0.005399985903242643,
#  0.006371930409828863,
#  0.008448909940968696,
#  0.0041098242016145425,
#  0.02129128175840278,
#  0.006340249464958592,
#  0.013294863029459258,
#  0.008814287693843736,
#  0.0004165878360633535,
#  0.010162768473898187,
#  0.03359943725174053,
#  0.01900478443251008,
#  0.002927848617332418,
#  0.004508578633480309,
#  0.007942006096549381,
#  0.009418656355647315,
#  0.013167503882138498,
#  0.048395684165087216,
#  0.0180282482234001,
#  0.003357740768403006,
#  0.004529979597047373,
#  0.001836520182936452,
#  0.01068048752370876,
#  0.04147407224484145,
#  0.0017106404047422252,
#  0.006054242482845029,
#  0.0022925819604429076,
#  0.003023840771584352,
#  0.016396466961280165,
#  0.016034930873156106,
#  0.0012290941766502916,
#  0.0009187604850081632,
#  0.0022246224759465694,
#  0.0007502845248578138,
#  0.008717669959731666,
#  0.0038683037122694275,
#  0.016914850666913783,
#  0.00355320646034496,
#  0.032606373821756685,
#  0.0010738803142965603,
#  0.029121203873762713,
#  0.012144493099786935,
#  0.0010316036588228217,
#  0.04575640148165061,
#  0.023066460517885412,
#  0.0031840462725639673,
#  0.005939607207690378,
#  0.000991550770896743,
#  0.0027032823303935194,
#  0.023622498648889545,
#  0.01359541192230207,
#  0.009119480566406768,
#  0.022151542115582457,
#  0.004271701266095551,
#  0.006370751008549225,
#  0.0052427531160905705,
#  7.470215141758274e-05,
#  0.0057132541196398545,
#  0.002883144829666451,
#  0.0041465649098757495,
#  0.00039908061949556206,
#  0.014057703500019336,
#  0.0005482273059709275,
#  0.007603598693596947,
#  0.002582962706973002,
#  0.008480843923206027,
#  0.008546990108575403,
#  0.004881768505869077,
#  0.009681095479412094,
#  0.0012243178006038358,
#  0.01672408186780583,
#  0.01096061029086548,
#  0.008027077589428444,
#  0.0008448512377255968,
#  0.0033143986433931127,
#  0.0012965689393417135,
#  0.00607989246411722]

# %% [markdown]
# # Question 4
#
# * Pull 100 uniformly random numbers from the interval $[0,1]$ into an array `xs`.
# * Pull 100 random numbers from the Gaussion distribution with $\mu=0$ and $\sigma=1.0$ into an array `ys`.
# * Scatter plot `xs` against `ys` using `matplotlib`

# %%
import matplotlib.pyplot as plt

xs=np.random.random(100)
ys=np.random.normal(loc=0,scale=1,size=100)
plt.scatter(xs,ys)

# %% [markdown]
# # Question 5
#
# Using the `numpy` library
#
#
# * Pull a random $100\times 100$ matrix
# * Calculate its 100-th power
# * Calculate its eigen-values
# * Calculate is [Singular Value Decomposition](https://numpy.org/doc/stable/reference/generated/numpy.linalg.svd.html)

# %%
matrix=np.random.random((100,100))
matrix=np.linalg.matrix_power(matrix,100)
w,v=np.linalg.eig(matrix)
a=np.linalg.svd(v)
a
# Out:
# (array([[ 0.01987717-2.58432087e-17j, -0.0464398 -2.39064584e-18j,
#           0.0321073 +3.66141069e-17j, ...,  0.05580817+3.26145900e-16j,
#           0.1011277 -4.17347433e-16j, -0.06037909-5.33826951e-16j],
#         [ 0.01022007+4.96828124e-18j, -0.02482997-3.27567449e-18j,
#          -0.02199421+5.94876007e-18j, ...,  0.08253896+1.16605984e-15j,
#          -0.04320324+3.16959665e-16j, -0.21571849-4.50126549e-16j],
#         [ 0.03076648+4.78534878e-18j,  0.01614749-8.61280194e-18j,
#          -0.01151837+1.23102609e-17j, ...,  0.16470838+2.89303358e-15j,
#           0.31696318-4.74204620e-15j, -0.23071111-1.01917059e-15j],
#         ...,
#         [ 0.0091166 +1.56701875e-17j,  0.04918044-3.54395458e-19j,
#           0.04110789-3.27904599e-17j, ..., -0.04606171-4.37285039e-17j,
#          -0.03759465+2.37689488e-16j,  0.03513522+1.31342140e-16j],
#         [-0.0013192 -3.44835425e-17j, -0.2484773 -3.81357781e-17j,
#           0.02859487-2.60379195e-18j, ...,  0.03279087-6.11566426e-16j,
#           0.24989611-3.86853076e-15j,  0.19656136+1.40718113e-18j],
#         [-0.03868959+1.58057254e-17j,  0.02896727-2.02930673e-17j,
#          -0.05173206-1.45579688e-17j, ..., -0.10522439-1.75365730e-15j,
#          -0.06161192+1.53712075e-15j, -0.06414014-1.11948503e-16j]]),
#  array([3.04288636, 2.83076366, 2.6870758 , 2.46970877, 2.280316  ,
#         2.21534076, 2.03956738, 1.88888906, 1.86508844, 1.80818739,
#         1.77900707, 1.7262603 , 1.65345686, 1.59465843, 1.49214834,
#         1.46637378, 1.39992791, 1.35251053, 1.27523515, 1.21932802,
#         1.11656622, 1.1108213 , 1.08791702, 1.06033561, 1.02406009,
#         0.99588666, 0.97861688, 0.96613872, 0.95568087, 0.92660543,
#         0.8976621 , 0.86512565, 0.85616598, 0.82592271, 0.76762371,
#         0.73830502, 0.70966261, 0.67738323, 0.66985273, 0.65251114,
#         0.628109  , 0.62065825, 0.58473837, 0.56598154, 0.54976004,
#         0.5237351 , 0.51142782, 0.49306507, 0.47162623, 0.46851185,
#         0.45645263, 0.42623387, 0.41746974, 0.40608764, 0.38838706,
#         0.37626744, 0.35790736, 0.35055081, 0.32629903, 0.32157088,
#         0.31266979, 0.3055167 , 0.29303735, 0.28548668, 0.27726616,
#         0.25973668, 0.2538755 , 0.24774056, 0.2408205 , 0.23305072,
#         0.22741593, 0.2136497 , 0.20325411, 0.19979313, 0.19171735,
#         0.17397617, 0.16573196, 0.16299117, 0.16045264, 0.1561773 ,
#         0.14313181, 0.13479807, 0.13372358, 0.12288222, 0.10776475,
#         0.1056062 , 0.09376117, 0.08802063, 0.08355299, 0.0794373 ,
#         0.07475985, 0.07087519, 0.0663489 , 0.06227108, 0.05459701,
#         0.04721663, 0.04425848, 0.03709982, 0.02886128, 0.01544481]),
#  array([[-6.29828995e-04+0.00000000e+00j,  1.15980992e-01+3.63018115e-04j,
#           1.15980992e-01-3.63018115e-04j, ...,
#          -2.41745483e-01+7.14316915e-03j, -2.41745483e-01-7.14316915e-03j,
#           1.52862926e-01-1.77809162e-17j],
#         [ 6.15710299e-04+0.00000000e+00j, -1.58950362e-01+1.23551185e-02j,
#          -1.58950362e-01-1.23551185e-02j, ...,
#          -1.21425638e-01-9.52706076e-03j, -1.21425638e-01+9.52706076e-03j,
#           4.23666343e-02-3.29606182e-17j],
#         [-1.06152500e-03+0.00000000e+00j,  1.15944195e-02-7.04629658e-03j,
#           1.15944195e-02+7.04629658e-03j, ...,
#           4.88189899e-02+2.15281511e-03j,  4.88189899e-02-2.15281511e-03j,
#           4.06877694e-02+4.72270986e-18j],
#         ...,
#         [ 1.10329394e-04+0.00000000e+00j, -1.45403299e-02-1.07611444e-02j,
#          -1.45403299e-02+1.07611444e-02j, ...,
#          -9.34754716e-02+6.52334184e-02j, -9.34754716e-02-6.52334184e-02j,
#           2.87278532e-02+9.28077060e-17j],
#         [ 1.12217939e-04+0.00000000e+00j, -5.78831148e-03-1.37335336e-03j,
#          -5.78831148e-03+1.37335336e-03j, ...,
#           2.85582238e-01+5.33057876e-01j,  2.85582238e-01-5.33057876e-01j,
#           1.09873586e-01+2.11419424e-15j],
#         [ 1.87038464e-04+0.00000000e+00j,  1.90564602e-03+5.35603187e-03j,
#           1.90564602e-03-5.35603187e-03j, ...,
#          -2.65282309e-02-1.65405918e-02j, -2.65282309e-02+1.65405918e-02j,
#           1.99996243e-03+1.39645240e-16j]]))

# %% [markdown]
# # Question 6
#
# * Pull the text of a novel by Dickens from the website of [Gutenberg Project](https://www.gutenberg.org/)
# * Remove all non-alphanumeric characters
# * Split the text into words and convert them into lower case
# * Count the number of distinct words in the  text
# * Count how many times each word occurs within the text

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re
from collections import Counter
from urllib import request
from bs4 import BeautifulSoup
import string 

url="https://www.gutenberg.org/files/564/564-h/564-h.htm"

html = request.urlopen(url).read().decode('utf8')
parsedHTML = BeautifulSoup(html, "html.parser")
readableText = parsedHTML.get_text() 
readable=readableText
words=readable.split()
words=words[0:500]  #how many words do you want to count
counter = dict() 

for i in range(len(words)):
    
    words[i]=words[i].lower()
    words[i] = words[i].translate(words[i].maketrans("", "", string.punctuation)) 
    
for word in words:  
    if word in counter: 
        counter[word] = counter[word] + 1
    else: 
        counter[word] = 1
for key in list(counter.keys()): 
    print(key, ":", counter[key])
# Out:
# the : 42
# mystery : 5
# of : 23
# edwin : 5
# drood : 5
# by : 7
# charles : 3
# dickens : 3
# project : 3
# gutenberg : 3
# ebook : 6
# illustrated : 1
# luke : 1
# fildes : 1
# this : 5
# is : 9
# for : 3
# use : 1
# anyone : 1
# anywhere : 1
# in : 12
# united : 2
# states : 2
# and : 16
# most : 1
# other : 1
# parts : 1
# world : 1
# at : 4
# no : 4
# cost : 1
# with : 3
# almost : 1
# restrictions : 1
# whatsoever : 1
# you : 3
# may : 2
# copy : 1
# it : 12
# give : 1
# away : 1
# or : 3
# reuse : 1
# under : 2
# terms : 1
# license : 1
# included : 1
# online : 1
# wwwgutenbergorg : 1
# if : 1
# are : 4
# not : 2
# located : 2
# youll : 1
# have : 1
# to : 5
# check : 1
# laws : 1
# country : 1
# where : 2
# before : 1
# using : 1
# title : 1
# author : 1
# release : 1
# date : 1
# 28 : 1
# 2020 : 1
# 564 : 1
# file : 1
# was : 1
# first : 2
# posted : 1
# on : 3
# april : 1
# 15 : 1
# 1996 : 1
# language : 1
# english : 3
# character : 1
# set : 3
# encoding : 1
# iso646us : 1
# usascii : 1
# start : 1
# transcribed : 1
# from : 4
# chapman : 1
# hall : 1
# 1914 : 1
# edition : 1
# david : 1
# price : 1
# email : 1
# ccx074pglaforg : 1
# chapter : 1
# i—the : 1
# dawn : 1
# an : 2
# ancient : 2
# cathedral : 4
# tower : 4
# how : 2
# can : 2
# be : 4
# here : 2
# wellknown : 1
# massive : 1
# gray : 1
# square : 1
# its : 2
# old : 2
# that : 4
# there : 1
# spike : 5
# rusty : 2
# iron : 1
# air : 1
# between : 1
# eye : 1
# any : 1
# point : 1
# real : 1
# prospect : 1
# what : 1
# intervenes : 1
# who : 1
# has : 4
# up : 2
# maybe : 1
# sultan’s : 1
# orders : 1
# impaling : 1
# a : 11
# horde : 1
# turkish : 1
# robbers : 1
# one : 2
# so : 2
# cymbals : 1
# clash : 1
# sultan : 1
# goes : 1
# his : 3
# palace : 1
# long : 1
# procession : 1
# ten : 2
# thousand : 2
# scimitars : 1
# flash : 1
# sunlight : 1
# thrice : 1
# dancinggirls : 1
# strew : 1
# flowers : 1
# then : 1
# follow : 1
# white : 1
# elephants : 1
# caparisoned : 1
# countless : 1
# gorgeous : 1
# colours : 1
# infinite : 1
# number : 1
# attendants : 1
# still : 2
# rises : 2
# background : 1
# cannot : 1
# writhing : 1
# figure : 1
# grim : 1
# stay : 1
# low : 1
# thing : 1
# as : 2
# top : 1
# post : 1
# bedstead : 2
# tumbled : 1
# all : 1
# awry : 1
# some : 1
# vague : 1
# period : 1
# drowsy : 1
# laughter : 1
# must : 1
# devoted : 1
# consideration : 1
# possibility : 1
# shaking : 1
# head : 1
# foot : 1
# man : 1
# whose : 1
# scattered : 1
# consciousness : 1
# thus : 1
# fantastically : 1
# pieced : 1
# itself : 1
# together : 1
# length : 1
# supports : 1
# trembling : 1
# frame : 1
# upon : 3
# arms : 1
# looks : 1
# around : 1
# he : 2
# meanest : 1
# closest : 1
# small : 1
# rooms : 1
# through : 1
# ragged : 1
# windowcurtain : 1
# light : 2
# early : 1
# day : 1
# steals : 1
# miserable : 1
# court : 1
# lies : 1
# dressed : 2
# across : 2
# large : 1
# unseemly : 1
# bed : 2
# indeed : 1
# given : 1
# way : 1
# weight : 1
# lying : 1
# also : 2
# longwise : 1
# chinaman : 1
# lascar : 1
# haggard : 1
# woman : 1
# two : 1
# sleep : 1
# stupor : 1
# last : 1
# blowing : 1
# kind : 1
# pipe : 1
# kindle : 1
# she : 1
# blows : 1
# shading : 1
# her : 1
# lean : 1
# hand : 1
# concentrates : 1
# red : 1
# spark : 1
# serves : 1
# dim : 1

# %% [markdown]
# # Question 7
#
# * Write a python function `CountWords` that takes the URL for a text and returns the number of unique words within the text.
# * Write a python function `Top20Words` that takes the URL for a text and returns the most frequently appearing top 20 words within the text.

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re
from collections import Counter
from urllib import request
from bs4 import BeautifulSoup
import string 


def Countwords(url):
    html = request.urlopen(url).read().decode('utf8')
    parsedHTML = BeautifulSoup(html, "html.parser")
    readableText = parsedHTML.get_text() 
    readable=readableText
    words=readable.split()
    words=words[0:100]
    unique=[]
    
    for i in range(len(words)):
    
        words[i]=words[i].lower()
        words[i] = words[i].translate(words[i].maketrans("", "", string.punctuation)) 
    
    for word in words:
        if word not in unique:
            unique.append(word)
    return len(unique)

def Top20Words(url):
    html = request.urlopen(url).read().decode('utf8')
    parsedHTML = BeautifulSoup(html, "html.parser")
    readableText = parsedHTML.get_text() 
    readable=readableText
    words=readable.split()
    words=words[0:100]
    counter = dict() 
    keys=[]
    for i in range(len(words)):

        words[i]=words[i].lower()
        words[i] = words[i].translate(words[i].maketrans("", "", string.punctuation)) 

    for word in words:  
        if word in counter: 
            counter[word] = counter[word] + 1
        else: 
            counter[word] = 1
    words=dict(sorted(counter.items(), key=lambda item: item[1]))
    key_list = list(words.keys())
    key_list.reverse()
    result=key_list[0:20]
    return result
mostcommon=Top20Words(url)
unique=Countwords(url)
# Out:
# 60

# %% [markdown]
# # Question 8
#
# * Pull the [IMKB](https://archive.ics.uci.edu/ml/machine-learning-databases/00247/data_akbilgic.xlsx) data from UCI using pandas.
# * Plot the TL based ISE and USD based ISE columns together in the same graph.
# * Calculate how many times `NIKKEI` was higher than `FTSE`.

# %%
import pandas as pd

df = pd.read_excel ('data_akbilgic.xlsx')

#i couldnt read xlsx file
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-471-5ba9e3bf960e> in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_excel ('data_akbilgic.xlsx')
#
# ~\Desktop\sample_project\env\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~\Desktop\sample_project\env\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     822         self._io = stringify_path(io)
#     823
# --> 824         self._reader = self._engines[engine](self._io)
#     825
#     826     def __fspath__(self):
#
# ~\Desktop\sample_project\env\lib\site-packages\pandas\io\excel\_xlrd.py in __init__(self, filepath_or_buffer)
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      20         import_optional_dependency("xlrd", extra=err_msg)
# ---> 21         super().__init__(filepath_or_buffer)
#      22
#      23     @property
#
# ~\Desktop\sample_project\env\lib\site-packages\pandas\io\excel\_base.py in __init__(self, filepath_or_buffer)
#     351             self.book = self.load_workbook(filepath_or_buffer)
#     352         elif isinstance(filepath_or_buffer, str):
# --> 353             self.book = self.load_workbook(filepath_or_buffer)
#     354         elif isinstance(filepath_or_buffer, bytes):
#     355             self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# ~\Desktop\sample_project\env\lib\site-packages\pandas\io\excel\_xlrd.py in load_workbook(self, filepath_or_buffer)
#      34             return open_workbook(file_contents=data)
#      35         else:
# ---> 36             return open_workbook(filepath_or_buffer)
#      37
#      38     @property
#
# ~\Desktop\sample_project\env\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows, ignore_workbook_corruption)
#     168     # files that xlrd can parse don't start with the expected signature.
#     169     if file_format and file_format != 'xls':
# --> 170         raise XLRDError(FILE_FORMAT_DESCRIPTIONS[file_format]+'; not supported')
#     171
#     172     bk = open_workbook_xls(
#
# XLRDError: Excel xlsx file; not supported

# %% [markdown]
# # Question 9
#
# Using the [networkx](https://networkx.org/) library
#
# * Get the [adjacency matrix](https://en.wikipedia.org/wiki/Adjacency_matrix) of the [Peterson graph](https://en.wikipedia.org/wiki/Petersen_graph).
# * Calculate its eigen-values and eigen-vectors using the [numpy](https://numpy.org/) library.
# * Repeat the same for a [random 3-regular graph on 10 vertices](https://networkx.org/documentation/networkx-1.10/reference/generated/networkx.generators.random_graphs.random_regular_graph.html).

# %%
import networkx as nx
import matplotlib.pyplot as plt

Graph = nx.petersen_graph()
nx.draw_shell(Graph, nlist=[range(3, 15), range(10)], font_weight='bold',node_color=range(10),cmap=plt.cm.Blues,font_color='r',style='dotted')
plt.show()

A=np.array(nx.adjacency_matrix(Graph).todense())
v,w=np.linalg.eig(A)

# %%
a=
nx.draw_shell(Graph,nx.random_regular_graph(3,15) , font_weight='bold',node_color=range(10),cmap=plt.cm.Blues,font_color='r',style='dotted')
plt.show()
# Out:
#   File "<ipython-input-430-63190e983392>", line 1
#     a=
#       ^
# SyntaxError: invalid syntax
